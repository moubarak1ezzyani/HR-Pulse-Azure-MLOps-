# %% [markdown]
# # Trainig Process

# %%
file_path="../data/processed/extracted_skills_only.csv"

import pandas as pd
df_skills=pd.read_csv(file_path)

df_skills.head()
# Out:
#                                     extracted_skills
# 0  ['forecast', 'data', 'technologies', 'multivar...
# 1  ['math', 'technologies', 'code', 'distributed'...
# 2  ['written', 'collaborating', 'recherche', 'd3)...
# 3  ['data', 'technologies', 'time series data', '...
# 4  ['data', 'technologies', 'marketing', 'campaig...

# %%
file_path="../data/processed/dataset_with_skills.csv"

import pandas as pd
df_skills=pd.read_csv(file_path)

df_skills.head()
# Out:
#    index          Job Title  \
# 0      0  Sr Data Scientist
# 1      1     Data Scientist
# 2      2     Data Scientist
# 3      3     Data Scientist
# 4      4     Data Scientist
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  Founded  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY     1993
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA     1968
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA     1981
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland     2000
# ...
